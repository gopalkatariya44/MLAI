# %%
import pandas as pd #this is how I usually import pandas
import sys

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# Pandas version 1.2.4

# %% [markdown]
# # Create Data

# %%
zip?

# %%
# The inital set of baby names and bith rates
names = ['Bhrama','Jerry','Monika','Jinesh','Mushef']
births = [968, 155, 77, 578, 973]
#The data set will consist of 5 baby names and the number of births recorded for that year (1880).

# %%
names
# Out:
# ['Bhrama', 'Jerry', 'Monika', 'Jinesh', 'Mushef']

# %%
births
# Out:
# [968, 155, 77, 578, 973]

# %%
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bhrama', 968),
#  ('Jerry', 155),
#  ('Monika', 77),
#  ('Jinesh', 578),
#  ('Mushef', 973)]

# %%
pd.DataFrame?

# %% [markdown]
# # Export Data

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
# Out:
#     Names  Births
# 0  Bhrama     968
# 1   Jerry     155
# 2  Monika      77
# 3  Jinesh     578
# 4  Mushef     973

# %%
filename = 'births18800001.csv'
df.to_csv(filename,index=False,header=True)

# %% [markdown]
# # exercise

# %%
#payal's exer.
l = ['Bhrama','Jerry','Monika','Jinesh','Mushef']
c = [968, 155, 77, 578, 973]
d=[(l[i],c[j]) for i in range(len(l)) for j in range(len(c)) if i==j]
d

# %%
mst_list = []
name = ['Bhrama','Jerry','Monika','Jinesh','Mushef']
birth = [968, 155, 77, 578, 973]

for i in range(len(name)):
    for j in range(len(birth)):
         if i ==j:
            mst_list.append((name[i],birth[j]))
mst_list

# %%
mst_list.append?

#======completed the exer

# %% [markdown]
# # Read data

# %%
wine_filename = 'wine.csv'
df = pd.read_csv(wine_filename)
df.shape
# Out:
# (178, 14)

# %%
df.shape[0] # 178 observation / raws
# Out:
# 178

# %%
df.shape[1] # total no of columns
# Out:
# 14

# %%
df.head(7)
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
# 5     1    14.20        1.76  2.45  15.2  112     3.27        3.39
# 6     1    14.39        1.87  2.45  14.6   96     2.50        2.52
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735
# ...

# %%
type(df['Alcohol'])
# Out:
# pandas.core.series.Series

# %%
type(df.Wine)
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine                  178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Acl                   178 non-null    float64
#  5   Mg                    178 non-null    int64
#  6   Phenols               178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanth               178 non-null    float64
#  10  Color.int             178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD                    178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.columns[7]
# Out:
# 'Flavanoids'

# %%
df.index?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=178, step=1)

# %%
a = df.groupby('Wine')
type(a)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
a.sum()
# Out:
#       Alcohol  Malic.acid     Ash     Acl    Mg  Phenols  Flavanoids  \
# Wine
# 1      810.94      118.63  144.88  1005.2  6274   167.57      175.96
# 2      871.79      137.22  159.38  1436.9  6713   160.38      147.74
# 3      631.38      160.02  116.98  1028.0  4767    80.58       37.51
#
#       Nonflavanoid.phenols  Proanth   Color.int     Hue      OD  Proline
# Wine
# 1                    17.11   112.06  326.170000  62.660  186.31    65827
# 2                    25.82   115.75  219.150000  74.996  197.76    36885
# 3                    21.48    55.37  355.019999  32.770   80.81    30235

# %%
df.Wine.value_counts().count()
# Out:
# 3

# %%
df.Wine.count()
# Out:
# 178

# %%
df.sort_values(['Mg'], ascending=False)
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 95      2    12.47        1.52  2.20  19.0  162     2.50        2.27
# 69      2    12.21        1.19  1.75  16.8  151     1.85        1.28
# 73      2    12.99        1.67  2.60  30.0  139     3.30        2.89
# 78      2    12.33        0.99  1.95  14.8  136     1.90        1.85
# 96      2    11.81        2.12  2.74  21.5  134     1.60        0.99
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 129     2    12.04        4.30  2.38  22.0   80     2.10        1.75
# 82      2    12.08        1.13  2.51  24.0   78     2.00        1.58
# 66      2    13.11        1.01  1.70  15.0   78     2.98        3.18
# 67      2    12.37        1.17  1.92  19.6   78     2.11        2.00
# 89      2    12.08        1.33  2.30  23.6   70     2.20        1.59
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 95                   0.32     3.28       2.60  1.16  2.63      937
# ...

# %%
df['Ash'].max()
# Out:
# 3.23

# %% [markdown]
# ### Statistics

# %%
df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
df['vishal']  = df.Wine

# %%
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline  vishal
# ...

# %%
df.corr()
# Out:
#                           Wine   Alcohol  Malic.acid       Ash       Acl  \
# Wine                  1.000000 -0.328222    0.437776 -0.049643  0.517859
# Alcohol              -0.328222  1.000000    0.094397  0.211545 -0.310235
# Malic.acid            0.437776  0.094397    1.000000  0.164045  0.288500
# Ash                  -0.049643  0.211545    0.164045  1.000000  0.443367
# Acl                   0.517859 -0.310235    0.288500  0.443367  1.000000
# Mg                   -0.209179  0.270798   -0.054575  0.286587 -0.083333
# Phenols              -0.719163  0.289101   -0.335167  0.128980 -0.321113
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077 -0.351370
# Nonflavanoid.phenols  0.489109 -0.155929    0.292977  0.186230  0.361922
# Proanth              -0.499130  0.136698   -0.220746  0.009652 -0.197327
# Color.int             0.265668  0.546364    0.248985  0.258887  0.018732
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667 -0.273955
# ...
