# %%
import pandas as pd

# %%
df=pd.read_excel("All_IPL_Match_Scores_raw.xlsx")
df.head()
# Out:
#    Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0             1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1             2  League Match  Apr 19  2008     Mohali            Chennai
# 2             3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3             4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4             5  League Match  Apr 20  2008     Mumbai             Mumbai
#
#   Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0           Bangalore                    222                       3
# 1              Punjab                    240                       5
# 2               Delhi                    129                       8
# 3             Kolkata                    110                      10
# 4           Bangalore                    165                       6
#
#    Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# ...

# %%
cl=df.groupby('Year')
cl

# %%
ans=cl.Match_Number.count()
ans
# Out:
# Year
# 2008    58
# 2009    57
# 2010    60
# 2011    72
# 2012    74
# 2013    76
# 2014    60
# 2015    57
# Name: Match_Number, dtype: int64

# %%
tmp=df[df['Winning_Team']=='FirstBatting']
tmp
# Out:
#      Match_Number         Match    Date  Year        Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008    Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008       Mohali            Chennai
# 7               8  League Match  Apr 23  2008      Chennai            Chennai
# 9              10  League Match  Apr 25  2008       Mohali             Punjab
# 14             15  League Match  Apr 28  2008    Bangalore            Chennai
# ..            ...           ...     ...   ...          ...                ...
# 505           506  League Match  May 14  2015       Mumbai             Mumbai
# 508           509  League Match  May 16  2015  Mumbai (BS)          Rajasthan
# 510           511   Qualifier 1  May 19  2015       Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015         Pune          Bangalore
# 513           514         Final  May 24  2015      Kolkata             Mumbai
#
# ...

# %%
z1=tmp.groupby('Year')
z1.Match_Number.count()
# Out:
# Year
# 2008    22
# 2009    26
# 2010    31
# 2011    32
# 2012    34
# 2013    37
# 2014    22
# 2015    32
# Name: Match_Number, dtype: int64

# %%
ans=pd.concat([ans,z1.Match_Number.count()],axis=1)
ans
# Out:
#       Match_Number  Match_Number
# Year
# 2008            58            22
# 2009            57            26
# 2010            60            31
# 2011            72            32
# 2012            74            34
# 2013            76            37
# 2014            60            22
# 2015            57            32

# %%
z2=df[df['Winning_Team']=='Chasing'].groupby('Year')
ans=pd.concat([ans,z2.Match_Number.count()],axis=1)
ans
# Out:
#       Match_Number  Match_Number  Match_Number
# Year
# 2008            58            22            36
# 2009            57            26            30
# 2010            60            31            28
# 2011            72            32            40
# 2012            74            34            40
# 2013            76            37            37
# 2014            60            22            37
# 2015            57            32            24

# %%
z3=df[df['Winning_Team']=='Match Tied'].groupby('Year')
ans=pd.concat([ans,z3.Match_Number.count()],axis=1)
ans
# Out:
#       Match_Number  Match_Number  Match_Number  Match_Number
# Year
# 2008            58            22            36           NaN
# 2009            57            26            30           1.0
# 2010            60            31            28           1.0
# 2011            72            32            40           NaN
# 2012            74            34            40           NaN
# 2013            76            37            37           2.0
# 2014            60            22            37           1.0
# 2015            57            32            24           1.0

# %%
ans=ans.fillna(0,downcast='infer')
ans.columns=['Total Number of Matches','Number of matches Team Batting First Won','Number of matches team Chasing Won','Number of times Match Tied']
ans
# Out:
#       Total Number of Matches  Number of matches Team Batting First Won  \
# Year
# 2008                       58                                        22
# 2009                       57                                        26
# 2010                       60                                        31
# 2011                       72                                        32
# 2012                       74                                        34
# 2013                       76                                        37
# 2014                       60                                        22
# 2015                       57                                        32
#
#       Number of matches team Chasing Won  Number of times Match Tied
# Year
# 2008                                  36                           0
# 2009                                  30                           1
# 2010                                  28                           1
# ...

# %%
df['Venue'].value_counts().max()
# Out:
# 62

# %%
t=df['Bat_First_Run_Rate'].max()

# %%
df[df['Bat_First_Run_Rate']==t]
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 390           391  League Match  May 18  2013  Bangalore          Bangalore
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 390             Chennai                    106                       2
#
#      Bat_First_Overs_Consumed          ...           Bat_Second_10_ov_score  \
# 390                       8.0          ...                              NaN
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 390                         NaN                      NaN
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 390                     NaN                         NaN
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 390                     NaN                    NaN
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 390                         NaN    Evening                   NaN
#
# [1 rows x 43 columns]

# %%
zp=df[df['Bat_First_Run_Rate']==t]
print(zp.Match_Number,zp.Team_Batting_First,zp.Bat_First_Runs_Scored,zp.Bat_First_Overs_Consumed)
# Out:
# 390    391
# Name: Match_Number, dtype: int64 390    Bangalore
# Name: Team_Batting_First, dtype: object 390    106
# Name: Bat_First_Runs_Scored, dtype: int64 390    8.0
# Name: Bat_First_Overs_Consumed, dtype: float64
