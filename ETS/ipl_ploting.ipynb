# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/gopalkatariya/Documents/MLAI/data/All_IPL_Match_Scores_Easy.xlsx")
df
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008     Mohali            Chennai
# 2               3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# ..            ...           ...     ...   ...        ...                ...
# 509           510  League Match  May 17  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
# 512           513   Qualifier 2  May 22  2015     Ranchi          Bangalore
# 513           514         Final  May 24  2015    Kolkata             Mumbai
#
# ...

# %%
year_count =  df.Year.value_counts()
year_count
# Out:
# 2013    76
# 2012    74
# 2011    72
# 2010    60
# 2014    60
# 2008    58
# 2009    57
# 2015    57
# Name: Year, dtype: int64

# %%
pd.concat([year_count])
# Out:
# 2013    76
# 2012    74
# 2011    72
# 2010    60
# 2014    60
# 2008    58
# 2009    57
# 2015    57
# Name: Year, dtype: int64

# %%
plt.plot(df.Date.head(12),df["Bat_First_Runs_Scored"].head(12))
plt.plot(df.Date.head(12),df["Bat_Second_Runs_Scored"].head(12))

# %%
plt.plot([2008,2009,2010,2011,2012,2013,2014],[76,74,72,60,58,57,57])
year_count = pd.concat([year_count])
# plt.plot(year_count)
plt.axis([2007,2015,56,78])
# Out:
# (2007.0, 2015.0, 56.0, 78.0)

# %%
df.isnull().sum()
# Out:
# Match_Number                    0
# Match                           0
# Date                            0
# Year                            0
# Venue                           0
# Team_Batting_First              0
# Team_Batting_Second             0
# Bat_First_Runs_Scored           0
# Bat_First_Wickets_Lost          0
# Bat_First_Overs_Consumed        0
# Bat_First_Overs_Allocated       0
# Bat_Second_Runs_Scored          0
# Bat_Second_Wickets_Lost         0
# Bat_Second_Overs_Consumed       0
# Bat_Second_Overs_Allocated      0
# Winner                          0
# Winning_Team                    0
# Winning_Margin                  6
# Win_Type                        6
# Bat_First_Run_Rate              0
# Bat_Second_Run_Rate             0
# Balls_Remaining                 0
# Bat_First_5_ov_score            0
# Bat_First_5_ov_wkts_lost        0
# Bat_First_10_ov_score           1
# Bat_First_10_ov_wkts_lost       1
# Bat_First_15_ov_score           8
# ...

# %%
year_count = pd.concat([year_count])
plt.plot(year_count)
