# %%
import pandas as pd

# %%
df=pd.read_excel("/Users/gopalkatariya/Documents/MLAI/ETS/All_IPL_Match_Scores_Easy.xlsx")
df.head()
# Out:
#    Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0             1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1             2  League Match  Apr 19  2008     Mohali            Chennai
# 2             3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3             4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4             5  League Match  Apr 20  2008     Mumbai             Mumbai
#
#   Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0           Bangalore                    222                       3
# 1              Punjab                    240                       5
# 2               Delhi                    129                       8
# 3             Kolkata                    110                      10
# 4           Bangalore                    165                       6
#
#    Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# ...

# %%
bat_first_run_rate =  df['Bat_First_Run_Rate'].head(10)

# %%
venue = df['Venue'].head(10)

# %%
bat_first_run_rate
# Out:
# 0    11.100000
# 1    12.000000
# 2     6.450000
# 3     5.892857
# 4     8.250000
# 5     8.300000
# 6     7.100000
# 7    10.400000
# 8    10.700000
# 9     9.100000
# Name: Bat_First_Run_Rate, dtype: float64

# %%
venue
# Out:
# 0    Bangalore
# 1       Mohali
# 2        Delhi
# 3      Kolkata
# 4       Mumbai
# 5       Jaipur
# 6    Hyderabad
# 7      Chennai
# 8    Hyderabad
# 9       Mohali
# Name: Venue, dtype: object
